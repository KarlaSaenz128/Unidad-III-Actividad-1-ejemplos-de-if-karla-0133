# %% [markdown]
# <a href="https://colab.research.google.com/github/KarlaSaenz128/Unidad-III-Actividad-1-ejemplos-de-if-karla-0133/blob/main/Copia_de_Copia_de_UIII_Act1_ejemplos_de_if_Karla_Saenz_0133.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Karla Saenz NL = 48 Gpo 2H fcha 6/mayo/2026
# #### Ejemplos de if , if else , if elif

# %% [markdown]
# #### Ejemplo de if

# %%
# 1. Estructura if simple
# Se utiliza cuando se desea ejecutar un bloque de código solo si se cumple una condición específica
# .
# Ejemplo: Verificar si un número es par usando aritmética y relaciones
numero = 10

if numero % 2 == 0:
    print("El número es par.")
# Out:
# El número es par.

# %%
# 1. Estructura if simple
# Se utiliza cuando se desea ejecutar un bloque de código solo si se cumple una condición específica
# .
# Ejemplo: Verificar si un número es par usando aritmética y relaciones
numero = 8

if numero % 2 == 0:
    print("El número es par.")
# Out:
# El número es par.

# %%
# 2 Ejemplo: Determinar si una persona puede votar (Edad y nacionalidad)
edad = 20
es_ciudadano = True

if edad >= 18 and es_ciudadano:
    print("Puedes votar.")
else:
    print("No cumples los requisitos para votar.")
# Descripción del código:
# Out:
# Puedes votar.

# %%
# 2 Ejemplo: Determinar si una persona puede votar (Edad y nacionalidad)
edad = 17
es_ciudadano = True

if edad >= 17 and es_ciudadano:
    print("no puedes votar.")
else:
    print("No cumples los requisitos para votar.")
# Descripción del código:
# Out:
# no puedes votar.

# %%
# Ejemplo: Clasificar una nota académica y aplicar un ajuste aritmético
puntuacion = 85
ajuste = 5
nota_final = puntuacion + ajuste

if nota_final >= 90:
    print("Calificación: Excelente")
elif nota_final >= 80:
    print("Calificación: Muy bueno")
elif nota_final >= 70:
    print("Calificación: Bueno")
else:
    print("Calificación: Necesita mejorar")
# Out:
# Calificación: Excelente

# %%
# Ejemplo: Clasificar una nota académica y aplicar un ajuste aritmético
puntuacion = 15
ajuste = 10
nota_final = puntuacion + ajuste

if nota_final >= 90:
    print("Calificación: Excelente")
elif nota_final >= 80:
    print("Calificación: Muy bueno")
elif nota_final >= 70:
    print("Calificación: Bueno")
else:
    print("Calificación: Necesita mejorar")
# Out:
# Calificación: Necesita mejorar

# %%
# Ejemplo: Clasificar una nota académica y aplicar un ajuste aritmético
puntuacion = 40
ajuste = 40
nota_final = puntuacion + ajuste

if nota_final >= 90:
    print("Calificación: Excelente")
elif nota_final >= 80:
    print("Calificación: Muy bueno")
elif nota_final >= 60:
    print("Calificación: Bueno")
else:
    print("Calificación: Necesita mejorar")
# Out:
# Calificación: Muy bueno

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/KarlaSaenz128/Unidad-III-Actividad-1-ejemplos-de-if-karla-0133/refs/heads/main/Act1%20infografiaifelsea.png)
